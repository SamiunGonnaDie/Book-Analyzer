# %% [markdown]
# # Loading the data

# %%
with open("miracle-in-the-andes.txt", "r", encoding="utf-8") as file:
    book = file.read()

# %% [markdown]
# # Most used Words without ARTICLES

# %%
import re
pattern = re.compile("[a-zA-Z]+")
findings = re.findall(pattern, book.lower())
findings[:5]
# Out:
# ['chapter', 'before', 'it', 'was', 'friday']

# %%
d = {}
for word in findings:
    if word in d.keys():
        d[word] = d[word] + 1
    else:
        d[word] = 1

# %%
d_list = [(value, key) for (key, value) in d.items()]
d_list = sorted(d_list, reverse = True)
d_list[:5]
# Out:
# [(5346, 'the'), (2795, 'and'), (2729, 'i'), (2400, 'to'), (2060, 'of')]

# %%
# !pip3.13 install nltk
# Out:
# Requirement already satisfied: nltk in d:\pyhton\book analyzer\.venv\lib\site-packages (3.9.2)
# Requirement already satisfied: click in d:\pyhton\book analyzer\.venv\lib\site-packages (from nltk) (8.3.0)
# Requirement already satisfied: joblib in d:\pyhton\book analyzer\.venv\lib\site-packages (from nltk) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in d:\pyhton\book analyzer\.venv\lib\site-packages (from nltk) (2025.9.18)
# Requirement already satisfied: tqdm in d:\pyhton\book analyzer\.venv\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in d:\pyhton\book analyzer\.venv\lib\site-packages (from click->nltk) (0.4.6)
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
nltk.download('stopwords')
import nltk
from nltk.corpus import stopwords
english_stopwords = stopwords.words("english")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\alvia\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.

# %%
filtered_words = []
for count, word in d_list:
    if word not in english_stopwords:
        filtered_words.append((word, count))

# %%
filtered_words[:5]
# Out:
# [('would', 575), ('us', 519), ('said', 292), ('roberto', 284), ('could', 252)]

# %% [markdown]
# # Sentiment Analysis: Most positive & negative chapter?

# %%
from nltk.sentiment import SentimentIntensityAnalyzer
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\alvia\AppData\Roaming\nltk_data...
# True

# %%
analyzer = SentimentIntensityAnalyzer()

# %%
scores = analyzer.polarity_scores(book)

# %%
if scores["pos"]>scores["neg"]:
    print("Its a good text")
else:
    print("Bad TEXT")
# Out:
# Its a good text

# %% [markdown]
# # Chapters Sentiment Analysis

# %%
import re
pattern = re.compile("Chapter [0-9]+")
chapters = re.split(pattern, book)

# %%
len(chapters)
# Out:
# 11

# %%
chapter = chapters[1:]

# %%
for nr, chapter in enumerate(chapters):
    scores = analyzer.polarity_scores(chapter)
    print(nr+1, scores)
# Out:
# 1 {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
# 2 {'neg': 0.061, 'neu': 0.779, 'pos': 0.16, 'compound': 1.0}
# 3 {'neg': 0.12, 'neu': 0.726, 'pos': 0.154, 'compound': 0.9991}
# 4 {'neg': 0.145, 'neu': 0.751, 'pos': 0.105, 'compound': -0.9999}
# 5 {'neg': 0.141, 'neu': 0.721, 'pos': 0.138, 'compound': -0.9963}
# 6 {'neg': 0.118, 'neu': 0.742, 'pos': 0.141, 'compound': 0.9997}
# 7 {'neg': 0.124, 'neu': 0.761, 'pos': 0.115, 'compound': -0.9979}
# 8 {'neg': 0.136, 'neu': 0.761, 'pos': 0.103, 'compound': -0.9999}
# 9 {'neg': 0.12, 'neu': 0.786, 'pos': 0.094, 'compound': -0.9998}
# 10 {'neg': 0.097, 'neu': 0.824, 'pos': 0.079, 'compound': -0.9996}
# 11 {'neg': 0.086, 'neu': 0.733, 'pos': 0.181, 'compound': 1.0}
