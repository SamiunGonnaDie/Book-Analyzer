# %% [markdown]
# # Loading The Book

# %%
with open("miracle-in-the-andes.txt", "r", encoding="utf-8") as file:
    book = file.read()

# %%
type(book)
# Out:
# str

# %% [markdown]
# ## How Many Chapters?

# %% [markdown]
# ### With String Methods (not accurate)

# %%
book.count("Chapter")
# Out:
# 11

# %% [markdown]
# # With RegEx (Regular Expressions)

# %%
import re

# %%
pattern = re.compile("Chapter [0-9]+")
findings = re.findall(pattern, book)
len(findings)
# Out:
# 10

# %% [markdown]
# # Which are the sentences where "love" was used?

# %%
pattern = re.compile("[A-Z]{1}[^.]*[^a-zA-Z]+love[^a-zA-Z]+[^.]*.")
findings = re.findall(pattern, book)
len(findings)
# Out:
# 67

# %% [markdown]
# # What are the most used words?

# %%
pattern = re.compile("[a-zA-Z]+")
findings = re.findall(pattern, book.lower())
len(findings)
# Out:
# 86798

# %%
d = {}
for word in findings:
    if word in d.keys():
        d[word] = d[word] + 1
    else:
        d[word] = 1

# %%
d_list = [(value, key) for (key, value) in d.items()]
sort = sorted(d_list, reverse = True)

# %% [markdown]
# # Extract the paragraphs where "Love" was used

# %%
pattern = re.compile("[^\n]+love[^\n]+")
findings = re.findall(pattern,book)
paragraphs = findings

# %% [markdown]
# # Extract the chapter titles

# %%
pattern = re.compile("[a-zA-Z ,]+\n\n")
findings = re.findall(pattern,book)
findings = [item.strip("\n\n") for item in findings]
titles = findings

# %%
def find(w):
    pattern = re.compile("[a-zA-Z]+")
    findings = re.findall(pattern,book.lower())
    d = {}
    for word in findings:
        if word in d.keys():
            d[word] = d[word]+1
        else:
            d[word] = 1
    try:
        return d[w]
    except:
        return f'The book does not contain the word"{w}"'

# %% [markdown]
# # Calling the function

# %%
find("love")
# Out:
# 83

# %%
find("the")
# Out:
# 5346

# %% [markdown]
# # Loading the Book Again

# %%
with open("miracle-in-the-andes.txt", "r", encoding="utf-8") as file:
    book = file.read()

# %% [markdown]
# # Most used WORDS(Non-Articles)

# %%
import re
pattern = re.compile("[a-zA-Z]+")
findings = re.findall(pattern, book.lower())
findings[:5]
# Out:
# ['chapter', 'before', 'it', 'was', 'friday']

# %%
d = {}
for word in findings:
    if word in d.keys():
        d[word] = d[word] + 1
    else:
        d[word] = 1

# %%
d_list = [(value, key) for (key, value) in d.items()]
d_list = sorted(d_list, reverse = True)
d_list[:5]
# Out:
# [(5346, 'the'), (2795, 'and'), (2729, 'i'), (2400, 'to'), (2060, 'of')]

# %%
import nltk
from nltk.corpus import stopwords
english_stopwords = stopwords.words("english")

# %%
english_stopwords
